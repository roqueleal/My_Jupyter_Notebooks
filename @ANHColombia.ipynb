# %%
# !pip install networkx twitter wordcloud nltk

# %%
import analisis_twitter as at
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
at.main()
# Out:
# Término de búsqueda: @ANHColombia
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# ...

# %%
at.main()
# Out:
# Término de búsqueda: @ECOPETROL_SA
# ...

# %%
at.main()
# Out:
# Término de búsqueda: #Ecopetrol
# ...

# %%
texto = at.main()
# Out:
# Término de búsqueda: #Ecopetrol

# %%
at.nube(texto)
